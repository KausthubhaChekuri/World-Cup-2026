# %%
import pandas as pd
import numpy as np
import sklearn

# %%
results_df = pd.read_csv("../data/archive/results.csv")
names_df = pd.read_csv("../data/archive/former_names.csv")
shootouts_df = pd.read_csv("../data/archive/shootouts.csv")
goalscorers_df = pd.read_csv("../data/archive/goalscorers.csv")

# %%
results_df
# Out:
#              date    home_team   away_team  home_score  away_score  \
# 0      1872-11-30     Scotland     England         0.0         0.0
# 1      1873-03-08      England    Scotland         4.0         2.0
# 2      1874-03-07     Scotland     England         2.0         1.0
# 3      1875-03-06      England    Scotland         2.0         2.0
# 4      1876-03-04     Scotland     England         3.0         0.0
# ...           ...          ...         ...         ...         ...
# 49489  2026-07-02  Switzerland     Algeria         NaN         NaN
# 49490  2026-07-03    Australia       Egypt         NaN         NaN
# 49491  2026-07-03    Argentina  Cape Verde         NaN         NaN
# 49492  2026-07-03     Colombia       Ghana         NaN         NaN
# 49493  2026-07-04       Canada     Morocco         NaN         NaN
#
#            tournament           city        country  neutral
# 0            Friendly        Glasgow       Scotland    False
# ...

# %%
names_df
# Out:
#                 current                                former  start_date  \
# 0                 Benin                               Dahomey  1959-11-08
# 1          Burkina Faso                           Upper Volta  1960-04-14
# 2               Curaçao                  Netherlands Antilles  1957-03-03
# 3        Czechoslovakia                               Bohemia  1903-04-05
# 4        Czechoslovakia                   Bohemia and Moravia  1939-01-01
# 5        Czechoslovakia  Representation of Czechs and Slovaks  1993-03-24
# 6              DR Congo                         Belgian Congo  1948-05-25
# 7              DR Congo                    Congo-Léopoldville  1963-04-12
# 8              DR Congo                        Congo-Kinshasa  1965-01-09
# 9              DR Congo                                 Zaïre  1971-01-10
# 10             Djibouti                     French Somaliland  1947-12-05
# 11                Egypt                  United Arab Republic  1958-02-22
# ...

# %%
goalscorers_df
# Out:
#              date    home_team away_team         team              scorer  \
# 0      1916-07-02        Chile   Uruguay      Uruguay     José Piendibene
# 1      1916-07-02        Chile   Uruguay      Uruguay    Isabelino Gradín
# 2      1916-07-02        Chile   Uruguay      Uruguay    Isabelino Gradín
# 3      1916-07-02        Chile   Uruguay      Uruguay     José Piendibene
# 4      1916-07-06    Argentina     Chile    Argentina       Alberto Ohaco
# ...           ...          ...       ...          ...                 ...
# 47824  2026-06-29       Brazil     Japan       Brazil  Gabriel Martinelli
# 47825  2026-06-29      Germany  Paraguay     Paraguay        Julio Enciso
# 47826  2026-06-29      Germany  Paraguay      Germany         Kai Havertz
# 47827  2026-06-29  Netherlands   Morocco  Netherlands          Cody Gakpo
# 47828  2026-06-29  Netherlands   Morocco      Morocco           Issa Diop
#
#        minute  own_goal  penalty
# 0        44.0     False    False
# ...

# %%
shootouts_df
# Out:
#            date               home_team         away_team  \
# 0    1967-08-22                   India            Taiwan
# 1    1971-11-14             South Korea  Vietnam Republic
# 2    1972-05-07             South Korea              Iraq
# 3    1972-05-17                Thailand       South Korea
# 4    1972-05-19                Thailand          Cambodia
# ..          ...                     ...               ...
# 675  2026-03-31  Bosnia and Herzegovina             Italy
# 676  2026-03-31          Czech Republic           Denmark
# 677  2026-06-06               Lithuania            Latvia
# 678  2026-06-29                 Germany          Paraguay
# 679  2026-06-29             Netherlands           Morocco
#
#                      winner           first_shooter
# 0                    Taiwan                     NaN
# 1               South Korea                     NaN
# 2                      Iraq                     NaN
# 3               South Korea                     NaN
# ...
